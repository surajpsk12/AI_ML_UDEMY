# %%
from math import sqrt,pow 
print(sqrt(16))
print(pow(2,3))
# Out:
# 4.0
# 8.0

# %%
import datetime as dt
print(dt.datetime.now())
print(dt.datetime.now().year)
# Out:
# 2026-04-19 16:04:51.426146
# 2026

# %%
import random as rd 
print(rd.randint(1,100))
# Out:
# 82
